# %%
import cv2 as cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/hqdefault.jpg')

# %%
import os
os.chdir('/content/drive/MyDrive')

# %%
I = cv2.imread('/content/drive/MyDrive/Epic_logo_competition.jpeg')

# %%
# from google.colab.patches import cv2_imshow
cv2_imshow(I)
# Out:
# <PIL.Image.Image image mode=RGB size=1409x878>

# %%
I1 = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)
cv2_imshow(I1)
# Out:
# <PIL.Image.Image image mode=L size=1409x878>

# %%
from PIL import Image, ImageFilter
im=Image.open('/content/drive/MyDrive/Final_design.png')
im.show()

# %%
from PIL import ImageEnhance
enh = ImageEnhance.Contrast(im)
enh.enhance(1.8).show("30% more contrast")

# %%
I3=Image.open('/content/drive/MyDrive/00.JPG')
I3.show()

# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
I4=io.imread('/content/drive/MyDrive/Final_design.png')
io.imshow(I4)
plt.show()

# %%
I5=plt.imread('/content/drive/MyDrive/istockphoto-918813280-612x612.jpg')
plt.imshow(I5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import imageio.v3 as io
I6=io.imread('/content/drive/MyDrive/png_20230308_112715_0000.png')
plt.imshow(I6)
print(I6.shape)
# Out:
# (1920, 1080, 4)

# %%
import SimpleITK as sitk

I7=sitk.ReadImage('/content/drive/MyDrive/istockphoto-918813280-612x612.jpg')

nda=sitk.GetArrayFromImage(I7)

plt.imshow(nda)
plt.show()
